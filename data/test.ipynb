# %% [markdown]
# # Synthesize data from TREC-DL
#
# Process:
# 1. Get topics and qrels in Pyserini format
# 2. Retrieve top 100 documents using BM25 to generate rank results
# 3. Evaluate nDCG@10 performance
# 4. Convert to Huggingface format and upload to Huggingface Hub

# %% [markdown]
# ### step 123

# %%
import sys
sys.path.append('/home/mila/l/le.zhang/scratch/DeepRerank')
from pyserini.search import get_topics, get_qrels
# from pyserini.search.lucene import LuceneSearcher
from run_evaluation import THE_TOPICS, THE_INDEX
from trec_eval import EvalFunction
data = 'dl21'

# searcher = LuceneSearcher.from_prebuilt_index(THE_INDEX[data])
DLV2 = ['dl20', 'dl21', 'dl22', 'dl23']
topics = get_topics(THE_TOPICS[data] if data not in dl else data)
qrels = get_qrels(THE_TOPICS[data])

# %%
# 将dl21, dl22, dl23的qels txt 拼接在一起
import json
qrels = {}
for data in ['dl21', 'dl22', 'dl23']:
    qrels_file = get_qrels_file(THE_TOPICS[data])
    with open(qrels_file, 'r') as f:
        for line in f:
            qid, _, docid, rel = line.strip().split()
            if qid not in qrels:
                qrels[qid] = {}
            qrels[qid][docid] = int(rel)
           
# Save the combined qrels to a file
output_file = '/home/mila/l/le.zhang/scratch/DeepRerank/data/combined_qrels.txt'
with open(output_file, 'w') as f:
    for qid in sorted(qrels.keys()):
        for docid, rel in qrels[qid].items():
            f.write(f"{qid} 0 {docid} {rel}\n")
           
# sa

# %%
for data in ['dl21', 'dl22', 'dl23']:
    topics = get_topics(THE_TOPICS[data] if data not in dl else data)
    print(f"\nEvaluating {data}:, len(topics): {len(topics)}")
    EvalFunction.main(THE_TOPICS[data], f'/home/mila/l/le.zhang/scratch/DeepRerank/data/20{data[2:]}_passage_top100.txt')

# %% [markdown]
# ### step 4

# %%
# 读取3个top100文件，拼接在一起
combined_rank_results = []
for data in ['dl21', 'dl22', 'dl23']:
    with open(f'/home/mila/l/le.zhang/scratch/DeepRerank/data/{data}_bm25_rank_results.json', 'r') as f:
        rank_results = json.load(f)
        print(f"len(rank_results): {len(rank_results)}")
        combined_rank_results.extend(rank_results)

# %%
import copy
import random
replicate_rank_results = []
replicate_times = 50
for item in combined_rank_results:
    for _ in range(replicate_times):
        new_item = copy.deepcopy(item)
        # Randomly select 20 hits from original hits list
        new_item['hits'] = random.sample(new_item['hits'], min(20, len(new_item['hits'])))
        replicate_rank_results.append(new_item)

# %%
from datasets import Dataset
import pandas as pd
from huggingface_hub import login
df = pd.DataFrame(replicate_rank_results)
dataset = Dataset.from_pandas(df)

# Print dataset info
print(f"Dataset size: {len(dataset)}")
print(dataset)

# Upload the dataset to Huggingface Hub
dataset.push_to_hub(
    "le723z/TREC-DL-TOP100",  # Replace with your desired repository name
    private=False,  # Set to True if you want a private dataset
)

# %% [markdown]
# ## 合成训练数据集

# %%
"""
Preprocess dataset for countdown task - given a target number and N numbers, generate equations to reach target
"""

import re
import os
from datasets import Dataset, load_dataset
from random import randint, seed, choice
from typing import List, Tuple
from tqdm import tqdm
from hdfs_io import copy, makedirs
import argparse
import sys
sys.path.append('/home/mila/l/le.zhang/scratch/DeepRerank')
from trec_eval import eval_rerank


def make_prefix(dp, template_type):
    query = dp['query']
    hits = dp['hits']
    num_hits = len(hits)
    # NOTE: also need to change reward_score/countdown.py
    if template_type == 'base':
        raise NotImplementedError
    elif template_type == 'qwen-instruct':
        """This works for Qwen Instruct Models"""

        prefix = (
            f"I will provide you with passages, each indicated by number identifier []. Rank the passages based on their relevance to the search query."
            f"Search Query: {query}. \nRank the {num_hits} passages above based on their relevance to the search query."
            f"The passages should be listed in descending order using identifiers. The most relevant passages should be listed first. The output format should be <answer> [] > [] </answer>, e.g., <answer> [1] > [2] </answer>."
        )
    
        return prefix



raw_dataset = load_dataset('le723z/TREC-DL-TOP100', split='train')
all_metric, scores = eval_rerank('combined_qrels.txt', raw_dataset)
unsolvable_qids = []
for qid, metrics in scores.items():
    if metrics['ndcg_cut_10'] == 0:
        unsolvable_qids.append(qid)
unsolvable_qids, len(unsolvable_qids)
# Filter out samples with qids in unsolvable_qids
filtered_dataset = raw_dataset.filter(lambda x: str(x['hits'][0]['qid']) not in unsolvable_qids)
print(len(filtered_dataset))

def make_map_fn(split):
    def process_fn(example, idx):
        question = make_prefix(example, template_type="qwen-instruct")
        messages = [
                {"role": "system", "content": "You are DeepRerank, an intelligent assistant that can rank passages based on their relevancy to the search query. You first thinks about the reasoning process in the mind and then provides the user with the answer."},
                {"role": "user","content": question},
                {"role": "assistant", "content": "Okay, please provide the passages."}
            ]
        rank = 0
        for hit in example['hits']:
            rank += 1
            content = hit['content']
            content = content.replace('Title: Content: ', '')
            content = content.strip()
            content = ' '.join(content.split()[:int(300)]) # max token fea each passage is 300
            messages.append({"role": "user", "content": f"[{rank}] {content}"})
            messages.append({"role": "assistant", "content": f"Received passage [{rank}]."})
            
        messages.append({
            "role": "user",
           "content": f"""Please rank these passages according to their relevance to the search query: "{example['query']}"
                Follow these steps exactly:
                1. First, within <think> tags, analyze EACH passage individually:
                - Evaluate how well it addresses the query
                - Note specific relevant information or keywords
                - Assign a relevance score (1-5) with clear justification:
                  5: Directly answers the query with comprehensive, accurate information
                  4: Highly relevant with most key information but may lack some details
                  3: Moderately relevant with some useful information
                  2: Tangentially relevant with minimal useful information
                  1: Not relevant or off-topic

                2. Then, within <answer> tags, provide ONLY the final ranking in descending order of relevance using the format: [X] > [Y] > [Z]
                Your thinking process must directly inform your final ranking. The passages you determine most relevant in your analysis should be ranked highest in your answer."""
        })

        

        data = {
            "data_source": "TREC-DL-TOP100",
            "prompt": messages,
            "ability": "rerank",
            "reward_model": {
                "style": "rule",
                "ground_truth": ""
            },
            "extra_info": {
                'split': split,
                'index': idx,
            }
        }
        return data
    return process_fn

train_dataset = filtered_dataset.map(function=make_map_fn('train'), with_indices=True)

local_dir = './'
hdfs_dir = None

train_dataset.to_parquet(os.path.join(local_dir, 'filtered_train.parquet'))

if hdfs_dir is not None:
    makedirs(hdfs_dir)
    copy(src=local_dir, dst=hdfs_dir)

# %%
# 统计所有样本的token长度
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "Qwen/Qwen2.5-7B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)
from tqdm import tqdm
lengths = []
for i in tqdm(range(len(train_dataset))):
    text = tokenizer.apply_chat_template(
        train_dataset[i]['prompt'],
        tokenize=False,
        add_generation_prompt=True
    )
    model_inputs = tokenizer(text, return_tensors="pt")
    lengths.append(len(model_inputs['input_ids'][0]))
    
print(f"Average length: {sum(lengths)/len(lengths):.2f}")
print(f"Max length: {max(lengths)}")
print(f"Min length: {min(lengths)}")

# %% [markdown]
# ## 过滤 得分低于0.1的样本

# %%
from datasets import load_dataset
import sys
sys.path.append('/home/mila/l/le.zhang/scratch/DeepRerank')
from trec_eval import eval_rerank
dataset = load_dataset("parquet", data_files='filtered_train.parquet')["train"]

# %%
# Evaluate and filter based on NDCG@10 threshold using multiprocessing
from multiprocessing import Pool
from functools import partial

def process_example(example, idx):
    all_metric, scores = eval_rerank('combined_qrels.txt', example)
    example['metrics'] = all_metric
    if all_metric['NDCG@10'] < 0.1:
        print(f"Discarding example {idx} with metrics: {all_metric}")
        return None
    return example

def filter_dataset_parallel(dataset, num_processes=8):
    with Pool(processes=num_processes) as pool:
        results = list(pool.starmap(process_example, [(example, idx) for idx, example in enumerate(dataset)]))
    
    # Filter out None values and create new dataset
    filtered_examples = [ex for ex in results if ex is not None]
    filtered_dataset = dataset.from_list(filtered_examples)
    
    print(f"\nKept {len(filtered_dataset)} examples")
    return filtered_dataset

filtered_dataset = filter_dataset_parallel(dataset)

# %%
filtered_dataset.to_parquet(os.path.join(local_dir, 'filtered_train_high_ndcg.parquet'))

# %% [markdown]
# ## 测试模型zero-shot rerank的得分和随机初排的得分

# %%
import sys
sys.path.append('/home/mila/l/le.zhang/scratch/DeepRerank')
from datasets import load_dataset   

dataset = load_dataset("parquet", data_files='filtered_train_high_ndcg.parquet',split='train[:100]')

# %%
dataset[0]
# Out:
# {'query': 'what does prenatal care include',
#  'hits': [{'content': 'determines they are clinically necessary. • Delivery of one or more than one baby, including prenatal and postnatal medical care furnished by a physician or nurse midwife. Your benefits for prenatal and postnatal medical care by a physician or nurse midwife are included in the payment for the delivery.',
#    'docid': 'msmarco_passage_65_381245232',
#    'qid': 646091,
#    'rank': 85,
#    'score': 10.594099998474121},
#   {'content': 'The earlier you get prenatal care, the better your chances are for a healthy pregnancy and baby. What may happen at my first prenatal care visit? At your first prenatal care visit, your health care professional will ask you many questions. You will be asked the date of the first day of your last menstrual period.',
#    'docid': 'msmarco_passage_37_36647802',
#    'qid': 646091,
#    'rank': 41,
#    'score': 11.07289981842041},
#   {'content': 'Prenatal care is important for the health of both mother and baby. Common prenatal tests include ultrasound, amniocentesis, screening for group B strep and chronic villus sampling. Prenatal care also helps detect health conditions related to pregnancy, such as preeclampsia and gestational diabetes.',
#    'docid': 'msmarco_passage_53_592569309',
#    'qid': 646091,
#    'rank': 76,
#    'score': 10.724899291992188},
#   {'content': 'Medicaid coverage for prenatal care provides another opportunity to illustrate the four pathways’ differences and how each state determines what services to include. [1] Right away, we know that the emergency pathway will not pay for prenatal care because preventive services are non-urgent by definition.',
#    'docid': 'msmarco_passage_48_280793081',
#    'qid': 646091,
#    'rank': 20,
#    'score': 11.568300247192383},
#   {'content': 'Prenatal Screening for Down Syndrome. There are several options for Down syndrome prenatal screening. These include: A blood test and an ultrasound test during the first trimester of pregnancy. This is the most accepted approach for screening during the first trimester. A blood test enables a health care provider to check for "markers," such as certain proteins, in the mother\'s blood that suggest an increased likelihood of Down syndrome. 2 Then the health care provider does an ultrasound test, which uses high-frequency sound waves to create images.',
#    'docid': 'msmarco_passage_55_422869257',
#    'qid': 646091,
#    'rank': 48,
#    'score': 10.984097480773926},
#   {'content': 'It does appear that fewer family physicians are taking care of pregnant women. According to a study cited in the Graham Center report, prenatal care by family physicians declined in all geographic regions of the U.S. between 1980 and 1999, from 17.3 percent of all prenatal visits to 10.2 percent. 3.',
#    'docid': 'msmarco_passage_03_723004579',
#    'qid': 646091,
#    'rank': 97,
#    'score': 10.450799942016602},
#   {'content': 'Obstetrics & Gynecology. OB/GYN services at Mass General Waltham include routine and subspecialty gynecologic care, prenatal obstetrical care including ultrasounds and prenatal diagnostic services, pre- and postoperative care and treatments for urogynecologic issues. Orthopaedic Outpatient Clinics.',
#    'docid': 'msmarco_passage_53_253592504',
#    'qid': 646091,
#    'rank': 51,
#    'score': 10.900799751281738},
#   {'content': 'However, PUBS cannot be performed until later in the pregnancy, during the 18th to 22nd week. 5. Prenatal diagnostic testing does involve some risk to the mother and fetus, including a slight risk of miscarriage. 6, 7, 8, 9 If you and your family are considering prenatal diagnostic testing for Down syndrome, discuss all the risks and benefits with your health care provider.',
#    'docid': 'msmarco_passage_55_422841976',
#    'qid': 646091,
#    'rank': 69,
#    'score': 10.764898300170898},
#   {'content': 'Maternity and Newborn Care. This includes all maternity, delivery, and newborn care, although prenatal checkups are generally covered under preventive care (described above) and may be covered with no cost-sharing for the expectant mother. According to HRSA, prenatal care falls under the category of well-woman care.',
#    'docid': 'msmarco_passage_66_119411167',
#    'qid': 646091,
#    'rank': 88,
#    'score': 10.568900108337402},
#   {'content': 'What makes us unique is our integrated model of health care delivery. We are an integrated health delivery system, which means that we provide and coordinate the entire scope of care for our members, including: preventive care. well-baby and prenatal care. immunizations.',
#    'docid': 'msmarco_passage_44_853075903',
#    'qid': 646091,
#    'rank': 73,
#    'score': 10.741299629211426},
#   {'content': "What an MFM Doctor Does. An MFM doctor: Gives regular prenatal care for women with high-risk pregnancies. Helps manage the mother's existing health problems, such as diabetes and high blood pressure. Cares for women who develop complications during pregnancy or childbirth.",
#    'docid': 'msmarco_passage_10_630865817',
#    'qid': 646091,
#    'rank': 57,
#    'score': 10.857000350952148},
#   {'content': 'Trends in prenatal care utilization are commonly collected using the prenatal care record. Critical data include EGA at the initiation of care and number of visits. The prenatal care record serves to document data that are commonly used as indicators of quality and adequacy of care.',
#    'docid': 'msmarco_passage_47_609747966',
#    'qid': 646091,
#    'rank': 23,
#    'score': 11.40429973602295},
#   {'content': 'How Much Does Prenatal Care Cost? Prenatal care involves a series of doctor or midwife visits throughout the pregnancy to check the health of the patient and her fetus and make sure the pregnancy is progressing normally. Prenatal care allows a health professional to spot common problems with the potential to become dangerous if left untreated. Prenatal visits are recommended every month during the first six months of pregnancy; every two weeks during months seven and eight; and every week during month nine.',
#    'docid': 'msmarco_passage_00_546996726',
#    'qid': 646091,
#    'rank': 38,
#    'score': 11.091500282287598},
#   {'content': 'IMG Src: uticaparkclinic.com. Once you find out that you are pregnant, you should schedule a visit to your health care provider to begin prenatal care. Prenatal visits to your health care include a physical exam, weight checks, and urine sampling. It also includes a blood test and imaging test or ultrasound exams.',
#    'docid': 'msmarco_passage_59_580811532',
#    'qid': 646091,
#    'rank': 92,
#    'score': 10.53689956665039},
#   {'content': "Once you become pregnant, stop taking Prenatal Vitamins with DHEA and switch to a prenatal vitamin product that does not contain DHEA, like our Prenatal Vitamins. WHAT'S IN THE BOX. One box contains a 12-week supply in a safety-sealed plastic bottle. WHAT TO KNOW.",
#    'docid': 'msmarco_passage_22_349535409',
#    'qid': 646091,
#    'rank': 87,
#    'score': 10.571999549865723},
#   {'content': 'What is a prenatal visit? Prenatal care is the medical care you receive during pregnancy. Prenatal care visits start early on in your pregnancy and continue regularly until you deliver the baby. They typically include a physical exam, a weight check, and various tests.',
#    'docid': 'msmarco_passage_48_749998273',
#    'qid': 646091,
#    'rank': 6,
#    'score': 12.639498710632324},
#   {'content': 'Prenatal Care. Women who suspect they may be pregnant should schedule a visit to their health care provider to begin prenatal care. Prenatal visits to a health care provider usually include a physical exam, weight checks, and providing a urine sample.',
#    'docid': 'msmarco_passage_55_423408197',
#    'qid': 646091,
#    'rank': 31,
#    'score': 11.28539752960205},
#   {'content': 'How Much Does Prenatal Care Cost? Prenatal care involves a series of doctor or midwife visits throughout the pregnancy to check the health of the patient and her fetus and make sure the pregnancy is progressing normally. Prenatal care allows a health professional to spot common problems with the potential to become dangerous if left untreated. Prenatal visits are recommended every month during the first six months of pregnancy; every two weeks during months seven and eight; and every week during month nine.',
#    'docid': 'msmarco_passage_14_853672414',
#    'qid': 646091,
#    'rank': 39,
#    'score': 11.091499328613281},
#   {'content': 'However, PUBS cannot be performed until later in the pregnancy, during the 18th to 22nd week. 5. Prenatal diagnostic testing does involve some risk to the mother and fetus, including a slight risk of miscarriage. 6, 7, 8, 9 If you and your family are considering prenatal diagnostic testing for Down syndrome, discuss all the risks and benefits with your health care provider.',
#    'docid': 'msmarco_passage_55_422866120',
#    'qid': 646091,
#    'rank': 70,
#    'score': 10.764897346496582},
#   {'content': 'How much does prenatal care cost? On average, the total prenatal visits will cost anywhere from $1,700 to $3,000 for the entire nine months during the pregnancy. This is without insurance and doesn’t include the baby delivery.',
#    'docid': 'msmarco_passage_07_74139026',
#    'qid': 646091,
#    'rank': 15,
#    'score': 11.79640007019043}],
#  'data_source': 'TREC-DL-TOP100',
#  'prompt': [{'content': 'You are DeepRerank, an intelligent assistant that can rank passages based on their relevancy to the search query. You first thinks about the reasoning process in the mind and then provides the user with the answer.',
#    'role': 'system'},
#   {'content': 'I will provide you with passages, each indicated by number identifier []. Rank the passages based on their relevance to the search query.Search Query: what does prenatal care include. \nRank the 20 passages above based on their relevance to the search query.The passages should be listed in descending order using identifiers. The most relevant passages should be listed first. The output format should be <answer> [] > [] </answer>, e.g., <answer> [1] > [2] </answer>.',
#    'role': 'user'},
#   {'content': 'Okay, please provide the passages.', 'role': 'assistant'},
#   {'content': '[1] determines they are clinically necessary. • Delivery of one or more than one baby, including prenatal and postnatal medical care furnished by a physician or nurse midwife. Your benefits for prenatal and postnatal medical care by a physician or nurse midwife are included in the payment for the delivery.',
#    'role': 'user'},
#   {'content': 'Received passage [1].', 'role': 'assistant'},
#   {'content': '[2] The earlier you get prenatal care, the better your chances are for a healthy pregnancy and baby. What may happen at my first prenatal care visit? At your first prenatal care visit, your health care professional will ask you many questions. You will be asked the date of the first day of your last menstrual period.',
#    'role': 'user'},
#   {'content': 'Received passage [2].', 'role': 'assistant'},
#   {'content': '[3] Prenatal care is important for the health of both mother and baby. Common prenatal tests include ultrasound, amniocentesis, screening for group B strep and chronic villus sampling. Prenatal care also helps detect health conditions related to pregnancy, such as preeclampsia and gestational diabetes.',
#    'role': 'user'},
#   {'content': 'Received passage [3].', 'role': 'assistant'},
#   {'content': '[4] Medicaid coverage for prenatal care provides another opportunity to illustrate the four pathways’ differences and how each state determines what services to include. [1] Right away, we know that the emergency pathway will not pay for prenatal care because preventive services are non-urgent by definition.',
#    'role': 'user'},
#   {'content': 'Received passage [4].', 'role': 'assistant'},
#   {'content': '[5] Prenatal Screening for Down Syndrome. There are several options for Down syndrome prenatal screening. These include: A blood test and an ultrasound test during the first trimester of pregnancy. This is the most accepted approach for screening during the first trimester. A blood test enables a health care provider to check for "markers," such as certain proteins, in the mother\'s blood that suggest an increased likelihood of Down syndrome. 2 Then the health care provider does an ultrasound test, which uses high-frequency sound waves to create images.',
#    'role': 'user'},
#   {'content': 'Received passage [5].', 'role': 'assistant'},
#   {'content': '[6] It does appear that fewer family physicians are taking care of pregnant women. According to a study cited in the Graham Center report, prenatal care by family physicians declined in all geographic regions of the U.S. between 1980 and 1999, from 17.3 percent of all prenatal visits to 10.2 percent. 3.',
#    'role': 'user'},
#   {'content': 'Received passage [6].', 'role': 'assistant'},
#   {'content': '[7] Obstetrics & Gynecology. OB/GYN services at Mass General Waltham include routine and subspecialty gynecologic care, prenatal obstetrical care including ultrasounds and prenatal diagnostic services, pre- and postoperative care and treatments for urogynecologic issues. Orthopaedic Outpatient Clinics.',
#    'role': 'user'},
#   {'content': 'Received passage [7].', 'role': 'assistant'},
#   {'content': '[8] However, PUBS cannot be performed until later in the pregnancy, during the 18th to 22nd week. 5. Prenatal diagnostic testing does involve some risk to the mother and fetus, including a slight risk of miscarriage. 6, 7, 8, 9 If you and your family are considering prenatal diagnostic testing for Down syndrome, discuss all the risks and benefits with your health care provider.',
#    'role': 'user'},
#   {'content': 'Received passage [8].', 'role': 'assistant'},
#   {'content': '[9] Maternity and Newborn Care. This includes all maternity, delivery, and newborn care, although prenatal checkups are generally covered under preventive care (described above) and may be covered with no cost-sharing for the expectant mother. According to HRSA, prenatal care falls under the category of well-woman care.',
#    'role': 'user'},
#   {'content': 'Received passage [9].', 'role': 'assistant'},
#   {'content': '[10] What makes us unique is our integrated model of health care delivery. We are an integrated health delivery system, which means that we provide and coordinate the entire scope of care for our members, including: preventive care. well-baby and prenatal care. immunizations.',
#    'role': 'user'},
#   {'content': 'Received passage [10].', 'role': 'assistant'},
#   {'content': "[11] What an MFM Doctor Does. An MFM doctor: Gives regular prenatal care for women with high-risk pregnancies. Helps manage the mother's existing health problems, such as diabetes and high blood pressure. Cares for women who develop complications during pregnancy or childbirth.",
#    'role': 'user'},
#   {'content': 'Received passage [11].', 'role': 'assistant'},
#   {'content': '[12] Trends in prenatal care utilization are commonly collected using the prenatal care record. Critical data include EGA at the initiation of care and number of visits. The prenatal care record serves to document data that are commonly used as indicators of quality and adequacy of care.',
#    'role': 'user'},
#   {'content': 'Received passage [12].', 'role': 'assistant'},
#   {'content': '[13] How Much Does Prenatal Care Cost? Prenatal care involves a series of doctor or midwife visits throughout the pregnancy to check the health of the patient and her fetus and make sure the pregnancy is progressing normally. Prenatal care allows a health professional to spot common problems with the potential to become dangerous if left untreated. Prenatal visits are recommended every month during the first six months of pregnancy; every two weeks during months seven and eight; and every week during month nine.',
#    'role': 'user'},
#   {'content': 'Received passage [13].', 'role': 'assistant'},
#   {'content': '[14] IMG Src: uticaparkclinic.com. Once you find out that you are pregnant, you should schedule a visit to your health care provider to begin prenatal care. Prenatal visits to your health care include a physical exam, weight checks, and urine sampling. It also includes a blood test and imaging test or ultrasound exams.',
#    'role': 'user'},
#   {'content': 'Received passage [14].', 'role': 'assistant'},
#   {'content': "[15] Once you become pregnant, stop taking Prenatal Vitamins with DHEA and switch to a prenatal vitamin product that does not contain DHEA, like our Prenatal Vitamins. WHAT'S IN THE BOX. One box contains a 12-week supply in a safety-sealed plastic bottle. WHAT TO KNOW.",
#    'role': 'user'},
#   {'content': 'Received passage [15].', 'role': 'assistant'},
#   {'content': '[16] What is a prenatal visit? Prenatal care is the medical care you receive during pregnancy. Prenatal care visits start early on in your pregnancy and continue regularly until you deliver the baby. They typically include a physical exam, a weight check, and various tests.',
#    'role': 'user'},
#   {'content': 'Received passage [16].', 'role': 'assistant'},
#   {'content': '[17] Prenatal Care. Women who suspect they may be pregnant should schedule a visit to their health care provider to begin prenatal care. Prenatal visits to a health care provider usually include a physical exam, weight checks, and providing a urine sample.',
#    'role': 'user'},
#   {'content': 'Received passage [17].', 'role': 'assistant'},
#   {'content': '[18] How Much Does Prenatal Care Cost? Prenatal care involves a series of doctor or midwife visits throughout the pregnancy to check the health of the patient and her fetus and make sure the pregnancy is progressing normally. Prenatal care allows a health professional to spot common problems with the potential to become dangerous if left untreated. Prenatal visits are recommended every month during the first six months of pregnancy; every two weeks during months seven and eight; and every week during month nine.',
#    'role': 'user'},
#   {'content': 'Received passage [18].', 'role': 'assistant'},
#   {'content': '[19] However, PUBS cannot be performed until later in the pregnancy, during the 18th to 22nd week. 5. Prenatal diagnostic testing does involve some risk to the mother and fetus, including a slight risk of miscarriage. 6, 7, 8, 9 If you and your family are considering prenatal diagnostic testing for Down syndrome, discuss all the risks and benefits with your health care provider.',
#    'role': 'user'},
#   {'content': 'Received passage [19].', 'role': 'assistant'},
#   {'content': '[20] How much does prenatal care cost? On average, the total prenatal visits will cost anywhere from $1,700 to $3,000 for the entire nine months during the pregnancy. This is without insurance and doesn’t include the baby delivery.',
#    'role': 'user'},
#   {'content': 'Received passage [20].', 'role': 'assistant'},
#   {'content': 'Please rank these passages according to their relevance to the search query: "what does prenatal care include"\n                Follow these steps exactly:\n                1. First, within <think> tags, analyze EACH passage individually:\n                - Evaluate how well it addresses the query\n                - Note specific relevant information or keywords\n                - Assign a relevance score (1-5) with clear justification:\n                  5: Directly answers the query with comprehensive, accurate information\n                  4: Highly relevant with most key information but may lack some details\n                  3: Moderately relevant with some useful information\n                  2: Tangentially relevant with minimal useful information\n                  1: Not relevant or off-topic\n\n                2. Then, within <answer> tags, provide ONLY the final ranking in descending order of relevance using the format: [X] > [Y] > [Z]\n                Your thinking process must directly inform your final ranking. The passages you determine most relevant in your analysis should be ranked highest in your answer.',
#    'role': 'user'}],
#  'ability': 'rerank',
#  'reward_model': {'ground_truth': '', 'style': 'rule'},
#  'extra_info': {'index': 0, 'split': 'train'},
#  'metrics': {'MAP@1': 0.00694,
#   'MAP@10': 0.04802,
#   'MAP@5': 0.02465,
#   'NDCG@1': 0.66667,
#   'NDCG@10': 0.4269,
#   'NDCG@5': 0.4336,
#   'Recall@1': 0.00694,
#   'Recall@10': 0.05556,
#   'Recall@5': 0.02778}}
